# %% [markdown]
# # Day 3 Assignment

# %% [markdown]
# ## Part 1: Image Processing

# %%
# !pip install pillow

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open("anime.jpg")

plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %%
resize_img = img.resize((300,300))

plt.imshow(resize_img)
plt.axis("off")
plt.title("Resized Image")
plt.show()

# %%
flip_img = img.transpose(Image.FLIP_LEFT_RIGHT)

plt.imshow(flip_img)
plt.axis("off")
plt.title("Flipped Image")
plt.show()

# %% [markdown]
# ## Part 2: CSV File Analysis

# %%
import pandas as pd

df = pd.read_csv("fooddataset.csv/vsa_food_rv_train.csv")

df.head()
# Out:
#                                              Comment  Rating
# 0                                      Món ăn cực tệ     0.0
# 1  Mình thấy mọi người review tích cực nhưng thực...     0.0
# 2  Chắc với sinh viên thì ai cũng quen thuộc với ...     1.0
# 3  Nhiều hôm thèm lẩu riêu mà chỉ có một mình thì...     1.0
# 4  Không gian sạch sẽ.quán mới lên ra món hơi chậ...     1.0

# %%
df.describe(include="all")
# Out:
#        Comment        Rating
# count    22843  22841.000000
# unique   12923           NaN
# top       Ngon           NaN
# freq        18           NaN
# mean       NaN      0.759643
# std        NaN      0.427310
# min        NaN      0.000000
# 25%        NaN      1.000000
# 50%        NaN      1.000000
# 75%        NaN      1.000000
# max        NaN      1.000000

# %%
df.columns
# Out:
# Index(['Comment', 'Rating'], dtype='object')

# %%
sorted_df = df.sort_values(by="Rating", ascending=False)

sorted_df.head()
# Out:
#                                                  Comment  Rating
# 11423  Quanh khu này chỉ ăn được mỗi quán này! Nổi ti...     1.0
# 14316  Mình gọi phở gà thường 25k/bát. Mình thích quá...     1.0
# 14326  Ko thích đặt đồ ăn online cho lắm nhưng hôm đặ...     1.0
# 14323  Nhà hàng này đò ăn rất ngon, giá rẻ, phục vụ n...     1.0
# 14322  Cũng lâu rồi mình chưa ra Hà Nội. Đầu Tiên là ...     1.0

# %%
import matplotlib.pyplot as plt

rating_counts = df["Rating"].value_counts()

plt.figure(figsize=(6,4))
rating_counts.plot(kind="bar")

plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(6,6))

rating_counts.plot(kind="pie", autopct="%1.1f%%")

plt.title("Rating Distribution")
plt.ylabel("")

plt.show()
